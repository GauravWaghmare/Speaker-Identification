# %%
from scipy.io import wavfile as wav

# %%
import numpy

# %%
[rate, data] = wav.read("s1.wav")

# %%
rate
# Out:
# 12500

# %%
data
# Out:
# array([-17,   0,   0, ..., -33, -33, -33], dtype=int16)

# %%
# %matplotlib inline
import scipy.signal as signal
import matplotlib.pyplot as plt

# %%
b, a = signal.iirfilter(15, 0.144, rp=1, rs=100, btype='lowpass', analog=False, ftype='ellip')
w, h = signal.freqz(b, a)
plt.title('Digital filter frequency response')
plt.plot(w, 20*numpy.log10(numpy.abs(h)))
plt.title('Digital filter frequency response')
plt.ylabel('Amplitude Response [dB]')
plt.xlabel('Frequency (rad/sample)')
plt.grid()
plt.show()

# %%
b
# Out:
# array([  2.91332642e-05,  -2.91893520e-04,   1.38670267e-03,
#         -4.09445481e-03,   8.25369334e-03,  -1.16208385e-02,
#          1.07987694e-02,  -4.46109585e-03,  -4.46109585e-03,
#          1.07987694e-02,  -1.16208385e-02,   8.25369334e-03,
#         -4.09445481e-03,   1.38670267e-03,  -2.91893520e-04,
#          2.91332642e-05])

# %%
a
# Out:
# array([  1.00000000e+00,  -1.36048825e+01,   8.73148247e+01,
#         -3.50557084e+02,   9.84396248e+02,  -2.04754501e+03,
#          3.25838540e+03,  -4.03916874e+03,   3.93208364e+03,
#         -3.00586873e+03,   1.78962973e+03,  -8.14958604e+02,
#          2.74776290e+02,  -6.47624468e+01,   9.54199104e+00,
#         -6.62632386e-01])

# %%
filtered_data = signal.lfilter(b, a, data)

# %%
plt.plot(data)

# %%
filtered_data
# Out:
# array([ -4.95265491e-04,  -1.77583895e-03,  -4.49000610e-03, ...,
#         -8.10301737e+01,  -8.05754694e+01,  -7.87842157e+01])

# %%
plt.plot(filtered_data)
